# %%
# -----------------------------------------
# 🧪 Zadanie: Sprav analýzu skladových zásob
# -----------------------------------------

produkty = [
    {"nazov": "Mydlo", "cena": 2.5, "ks": 30},
    {"nazov": "Šampón", "cena": 5.0, "ks": 15},
    {"nazov": "Zubná pasta", "cena": 3.2, "ks": 25},
]

# -----------------------------------------
# 🔹 Funkcia 1: vypocitaj_celkovu_hodnotu(produkty)
# Vráť hodnotu zásob (cena * ks pre každý produkt)
# Napr. Mydlo: 2.5 * 30 = 75 ... atď.
# Výstup: číslo – celková hodnota zásob v sklade
# -----------------------------------------


# -----------------------------------------
# 🔹 Funkcia 2: najvacsi_pocet_ks(produkty)
# Vráť názov produktu, ktorý má najviac kusov na sklade
# Výstup: napr. "Mydlo"
# -----------------------------------------


# -----------------------------------------
# 🔹 Funkcia 3: zobraz_vysledky(hodnota, najprodukt)
# Vypíš hodnotu zásob a názov najviac skladovaného produktu
# -----------------------------------------


# -----------------------------------------
# 🔹 Funkcia 4: main()
# Zavolaj všetky funkcie a spoj ich logicky
# -----------------------------------------


# -----------------------------------------
# 🔹 Spustenie hlavného programu
# -----------------------------------------
# if __name__ == "__main__":
#     main()

# %%
# 🔹 Funkcia 1: vypocitaj_celkovu_hodnotu(produkty)
def vypocitaj_celkovu_hodnotu(produkty):

    predaj_produktov = {}
    celkovy_predaj = 0

    for produkt in produkty:
        nazov_produktu = produkt["nazov"]
        hodnota = produkt["cena"] * produkt["ks"]

        if nazov_produktu in predaj_produktov:
            predaj_produktov[nazov_produktu] += hodnota
        else:
            predaj_produktov[nazov_produktu] = hodnota
            
    for produkt in predaj_produktov:

        if produkt in predaj_produktov:
            celkovy_predaj += predaj_produktov[produkt]

    return celkovy_predaj

# 🔹 Funkcia 2: najvacsi_pocet_ks(produkty)
def najvacsi_pocet_ks(produkty):
    naj_produkt = None
    max_pocet = 0

    for produkt in produkty:
        pocet_skladom = produkt["ks"]

        if pocet_skladom > max_pocet:
            naj_produkt = produkt["nazov"]
            max_pocet = pocet_skladom
    
    return max_pocet, naj_produkt

# 🔹 Funkcia 3: zobraz_vysledky(hodnota, najprodukt)

def zobraz_vysledky(hodnota, najprodukt, max_ks):
    print(f"Produkt, ktorého máme najviac skladom je: {najprodukt} v počte {max_ks}ks.")
    print(f"Hodnota všetkých produktov na sklade je: {hodnota}€.")


def main():
    produkty = [
    {"nazov": "Mydlo", "cena": 2.5, "ks": 30},
    {"nazov": "Šampón", "cena": 5.0, "ks": 15},
    {"nazov": "Zubná pasta", "cena": 3.2, "ks": 25},
    ]

    max_ks, najprodukt = najvacsi_pocet_ks(produkty) #v tejto funkcii vraciame 2 premenne tak môžeme 2 premenne mať aj tu pre lepší zápis
    hodnota = vypocitaj_celkovu_hodnotu(produkty)

    zobraz_vysledky(hodnota, najprodukt, max_ks)

if __name__ == "__main__":
    main()
# Out:
# Produkt, ktorého máme najviac skladom je: Mydlo v počte 30ks.
# Hodnota všetkých produktov na sklade je: 230.0€.
